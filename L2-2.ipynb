# %% [markdown]
# 5. Create a 4X3 integer array (```arr1```) <br>
# 5.1. Print its attributes:
# - Shape <br>
# - Dimension <br>
# 5.2. Return array of items by taking the second column from all rows <br>
# 5.3. Create a random 4X3 integer array (```arr2```):<br>
# - Add two arrays<br>
# - modify the result array by calculating the square of each element.

# %% [markdown]
# # PANDAS

# %% [markdown]
# ## Giới thiệu

# %% [markdown]
# Pandas là một thư viện Python, sử dụng để làm việc với bộ dữ liệu (data sets). Đây là thư viện rất quan trong trong Khoa học dữ liệu
# - Khiến dữ liệu dễ đọc, dễ xử lý
# - Phân tích dữ liệu lớn
# - Dọn dẹp dữ liệu (Clean messy data sets)

# %% [markdown]
# ## Import thư viện

# %% [markdown]
# Mở cmd: ```pip install pandas```

# %%
# Import thư viện pandas
import pandas as pd

# %% [markdown]
# ## Pandas series

# %% [markdown]
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
print(type(myvar))

# %% [markdown]
# ### Labels (nhãn)

# %%
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)

print(myvar['z'])

# %% [markdown]
# ### Key/Value Objects as Series

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)

# %% [markdown]
# ## Dataframe

# %% [markdown]
# Multi-dimensional tables, with rows and columns

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
  }           # Dictionary

df = pd.DataFrame(data)
print(df)

# %% [markdown]
# ### Đặt tên index

# %%
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)

# %% [markdown]
# ### Tìm hàng / cột (Locate row / column)

# %% [markdown]
# ```loc```: Tìm bằng label name <br>
# ```iloc```: Tìm bằng vị trí index

# %% [markdown]
# #### Hàng (row)

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
  }           # Dictionary

df = pd.DataFrame(data)
print(df)

# %%
print(df.loc[0]) # Row 0  ## Single label
print(type(df.loc[0]))

# %%
print(df.loc[[0,1]])  # Row 0 and 1   ## List of labels

# %%
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)

# %%
print(df.loc['day1'])   # Single label

# %%
print(df.loc[['day1','day2']])  ## List of labels

# %% [markdown]
# #### Hàng và cột

# %%
print(df.loc['day1','calories'])

# %%
print(df.loc[['day1', 'day2'],'calories'])

# %%
print(df.iloc[:,1])

# %% [markdown]
# #### Cột

# %%
print(df['calories'])

# %%
# Hoặc
print(df.duration)

# %% [markdown]
# ### Lấy ra các giá trị trong dataframe

# %%
values = df.values   # trả về 1 array
print(values)

# %% [markdown]
# ## Conditional selection

# %%
df

# %%
df.calories > 400

# %%
new_df = df.loc[df.calories > 400]
new_df

# %%
df.loc[(df.calories > 380) & (df.duration <50)]

# %% [markdown]
# ## Đọc file csv

# %% [markdown]
# CSV: comma separated value (Các giá trị tách bởi dấu phẩy)

# %%
df = pd.read_csv('Iris.csv')  # Đọc file
# pd.read_excel

df  #print the entire Dataframe

# %%
df.head()  # Print ra 5 dòng đầu của dataframe

# %%
df.tail()  # Print ra 5 dòng cuối của dataframe

# %%
# Thông tin về data
print(df.info())

# %%
print(df.describe())

# %%
df['Species'].unique()

# %%
df['Species'].value_counts()

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ## MATPLOTLIB

# %% [markdown]
# ### Giới thiệu

# %% [markdown]
# Là công cụ để vẽ đồ thị đơn giản
# <!-- ![plot](plot.png) -->
# <img src="plot.png" alt="Alt Text" width="600" height="500">

# %% [markdown]
# Cmd: ```pip install matplotlib```

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Các loại đồ thị

# %% [markdown]
# #### Line Plot

# %% [markdown]
# ##### Plotting

# %%
# Tạo mảng
import numpy as np
xpoints = np.array([1, 8, 2])    # mảng chứa điểm thuộc trục x
ypoints = np.array([3, 10,0 ])   # mảng chứa điểm thuộc trục y

# Vẽ đồ thị bằng plot()
plt.plot(xpoints, ypoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])   # Có thể bỏ qua trục x
plt.plot(ypoints)
plt.show()

# %%
# Nhiều đường
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# ##### Marker

# %% [markdown]
# Nhấn mạnh, làm rõ mỗi điểm data <br>
# Marker có thể là: 'o', '*', '.', ',' ....... Có thể tìm hiểu ở link: https://matplotlib.org/stable/api/markers_api.html

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'v')   # circle marker
plt.show()

# %%
# Thay đổi kích thước marker
plt.plot(ypoints, marker = 'v', ms = 15)   # ms - marker size
plt.show()

# %%
# Thay đổi màu marker
plt.plot(ypoints, marker = 'o', ms = 15, mec = 'DeepPink', mfc = '#228B22')   # mec - marker edge color, mfc - marker face color
plt.show()

# %% [markdown]
# Link màu trong Python
# - https://www.w3schools.com/colors/colors_names.asp
# - https://www.w3schools.com/colors/colors_hexadecimal.asp

# %% [markdown]
# ##### Line

# %% [markdown]
# Các linestyle có thể dùng: <br>
# - 'solid' <default> or '-'
# - 'dotted' or ':'
# - 'dashed' or '--'
# - 'dashdot' or '-.'

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = ':')

# %% [markdown]
# Line Color

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted', color = 'hotpink', linewidth = 4)

# %% [markdown]
# Linewidth

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '5')
plt.show()

# %% [markdown]
# #### Scatter plot

# %%
# 2 mảng cùng độ dài
### Quan sát 13 bạn nhỏ
age = np.array([10,7,8,7,12,17,2,9,4,11,12,9,6])  # tuổi
focus = np.array([99,86,87,88,99,86,91,87,94,78,77,85,86])  # độ tập trung

plt.scatter(age, focus)
plt.show()

# %%
# So sánh nhiều tập data

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

# %% [markdown]
# #### Bar plot

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y
        , color = "orange"
        , width = 0.7    # mặc định 0.8
        )
plt.show()

# %% [markdown]
# #### Pie chart

# %%
y = np.array([35, 25, 25, 10])
mylabels = ["Math", "English", "Physics", "PE"]  # Thêm labels
plt.pie(y
        , labels = mylabels
        )
plt.show()

# %% [markdown]
# ### Labels / Grid / Subplot

# %% [markdown]
# #### Labels

# %% [markdown]
# ```plt.xlabel```: Tên trục x
# ```plt.ylabel```: tên trục y

# %%
import numpy as np
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# ```plt.title()```: Tên đồ thị

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y, label = "Male")

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.legend()  #chu thich

plt.show()

# %% [markdown]
# #### Grid

# %% [markdown]
# ```plt.grid()```

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

# %% [markdown]
# #### Subplot

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)   # (1 hàng, 2 cột, vị trí của plot đang vẽ là 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)    # (1 hàng, 2 cột, vị trí của plot đang vẽ là 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Size of figure

# %%
plt.figure(figsize=(8,4))
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

# %% [markdown]
# ## SEABORN

# %% [markdown]
# A powerful Python data visualization library built on top of matplotlib.

# %% [markdown]
# ```pip install seaborn```

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load a sample dataset
df = sns.load_dataset("tips")  # Restaurant tips dataset
df.head()

# %%
sns.scatterplot(data=df, x="total_bill", y="tip")
plt.title("Total Bill vs Tip")
plt.show()

# %%
sns.histplot(df["total_bill"], kde=True) #kde vẽ đường mịn=> dễ quan sát peak
plt.title("Distribution of Total Bill")
plt.show()

# %%
sns.boxplot(data=df, x="day", y="total_bill")
plt.title("Boxplot of Total Bill by Day")
plt.show()

# %%
sns.set(style="whitegrid", palette="pastel")

sns.barplot(data=df, x="day", y="total_bill", ci=None)
plt.title("Bar Plot of Total Bill by Day")
plt.show()

# %%
sns.pairplot(df, hue="sex")
plt.suptitle("Pairplot of Tips Dataset", y=1.02)
plt.show()

# %%
sns.lineplot(data=df, x='day', y='total_bill')
sns.lineplot(data=df, x='day', y='tip')

# %% [markdown]
# # PRACTICE

# %% [markdown]
# Tìm hiểu dataset Iris.cvs

# %% [markdown]
# 1. Scatter Plot of Petal Length vs Petal Width
# - Plot a scatter plot with ```petal_length``` on x-axis and ```petal_width``` on y-axis.
# - Color the points by species.
#
# 2. Histogram of Sepal Length
# - Plot the distribution of ```sepal_length```.
#
# 3. Boxplot by Species
# - Create a boxplot of ```sepal_width``` for each species.
#
# 4. Countplot of Species
# - Count how many samples there are for each species.
#
# 5. Pairplot
# - Use ```sns.pairplot()``` to visualize relationships between all numerical variables.
# - Color the points by species.
#
# 6. Compare Two Species
# - Filter the dataset to only include two species (e.g., versicolor and virginica).
# - Plot their ```petal_length``` and ```sepal_width``` as two line plots on the same figure.

# %%
df = pd.read_csv('Iris.csv')
df["Species"].value_counts()

# %%
x1 = df.loc[df['Species']=='Iris-setosa']['PetalLengthCm']
y1 = df.loc[df['Species']=='Iris-setosa']['PetalWidthCm']
x2 = df.loc[df['Species']=='Iris-versicolor']['PetalLengthCm']
y2 = df.loc[df['Species']=='Iris-versicolor']['PetalWidthCm']
x3 = df.loc[df['Species']=='Iris-virginica']['PetalLengthCm']
y3 = df.loc[df['Species']=='Iris-virginica']['PetalWidthCm']

# %%
list_hoa = df["Species"].unique().tolist()
list_hoa[0]

# %%
x = [[]]*len(list_hoa)
y = [[]]*len(list_hoa)
for i in range(len(list_hoa)):
    x[i] = df.loc[df['Species']==list_hoa[i]]['PetalLengthCm']
    y[i] = df.loc[df['Species']==list_hoa[i]]['PetalWidthCm']
    
for i in range(len(x)):
    plt.scatter(x[i], y[i])

# %%
plt.scatter(x1,y1)
plt.scatter(x2,y2)
plt.scatter(x3,y3)
plt.show()
